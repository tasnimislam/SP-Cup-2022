# %% [markdown]
# # Introduction
#
# This is our implementation of inceptionnet inspired model on raw wave dataset(time domain) dataset. Here one can just hit run all and results will be generated in 2 csv files as inteded. The weights and models will be also saved for reproducibility. Thus this notebook can be used to train custom version of our model and experiment further.

# %% [markdown]
# ### **!!! Disclaimer:**
#
# Here as we are using raw waveform without data generator, loading all 9000 evaluation files in a single dataset will exhaust the available ram, so we are generating 3 subsections for each predictions, please download those csv, and merge them manually, to get the final_predictions scores

# %% [markdown]
# # 0. Setup
#
# At first we are importing and setting up all the libraries to implement this solution. If some of the files are not installed in your device, please refer to the readme file for installation direction

# %%
# !pip install -r "requirement (1).txt"
# Out:
# Requirement already satisfied: notebook>=6.3.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from -r requirement (1).txt (line 1)) (6.4.11)
# Requirement already satisfied: tqdm>=4.60.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from -r requirement (1).txt (line 2)) (4.64.0)
# Requirement already satisfied: pandas>=1.2.4 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from -r requirement (1).txt (line 3)) (1.4.2)
# Requirement already satisfied: numpy>=1.19.2 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from -r requirement (1).txt (line 4)) (1.21.6)
# Requirement already satisfied: ast-tools>=0.1.4 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from -r requirement (1).txt (line 5)) (0.1.8)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from -r requirement (1).txt (line 6)) (1.0.2)
# Requirement already satisfied: scipy>=1.6.3 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from -r requirement (1).txt (line 7)) (1.8.0)
# Requirement already satisfied: matplotlib>=3.4.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from -r requirement (1).txt (line 8)) (3.5.1)
# Requirement already satisfied: scikit-image>=0.18.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from -r requirement (1).txt (line 9)) (0.19.2)
# Requirement already satisfied: tensorflow-gpu>=2.4.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from -r requirement (1).txt (line 11)) (2.8.0)
# Requirement already satisfied: keras>=2.4.3 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from -r requirement (1).txt (line 12)) (2.8.0)
# Requirement already satisfied: librosa==0.9.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from -r requirement (1).txt (line 14)) (0.9.1)
# Requirement already satisfied: audioread>=2.1.5 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from librosa==0.9.1->-r requirement (1).txt (line 14)) (2.1.9)
# Requirement already satisfied: joblib>=0.14 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from librosa==0.9.1->-r requirement (1).txt (line 14)) (1.1.0)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from librosa==0.9.1->-r requirement (1).txt (line 14)) (5.1.1)
# Requirement already satisfied: numba>=0.45.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from librosa==0.9.1->-r requirement (1).txt (line 14)) (0.55.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from librosa==0.9.1->-r requirement (1).txt (line 14)) (1.6.0)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from librosa==0.9.1->-r requirement (1).txt (line 14)) (0.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from librosa==0.9.1->-r requirement (1).txt (line 14)) (21.0)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from librosa==0.9.1->-r requirement (1).txt (line 14)) (0.10.3.post1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (1.8.0)
# Requirement already satisfied: nbformat in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (5.3.0)
# Requirement already satisfied: ipykernel in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (6.10.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (4.9.2)
# Requirement already satisfied: prometheus-client in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.13.3)
# Requirement already satisfied: nbconvert>=5 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (6.5.0)
# Requirement already satisfied: jinja2 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (3.1.1)
# Requirement already satisfied: ipython-genutils in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (1.5.4)
# Requirement already satisfied: argon2-cffi in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (21.3.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (6.1)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (5.1.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from notebook>=6.3.0->-r requirement (1).txt (line 1)) (7.2.1)
# Requirement already satisfied: colorama in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tqdm>=4.60.0->-r requirement (1).txt (line 2)) (0.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from pandas>=1.2.4->-r requirement (1).txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from pandas>=1.2.4->-r requirement (1).txt (line 3)) (2022.1)
# Requirement already satisfied: astor in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from ast-tools>=0.1.4->-r requirement (1).txt (line 5)) (0.8.1)
# Requirement already satisfied: libcst in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from ast-tools>=0.1.4->-r requirement (1).txt (line 5)) (0.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from scikit-learn>=0.24.2->-r requirement (1).txt (line 6)) (3.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from matplotlib>=3.4.1->-r requirement (1).txt (line 8)) (4.33.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from matplotlib>=3.4.1->-r requirement (1).txt (line 8)) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from matplotlib>=3.4.1->-r requirement (1).txt (line 8)) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from matplotlib>=3.4.1->-r requirement (1).txt (line 8)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from matplotlib>=3.4.1->-r requirement (1).txt (line 8)) (2.4.7)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from scikit-image>=0.18.1->-r requirement (1).txt (line 9)) (2.18.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from scikit-image>=0.18.1->-r requirement (1).txt (line 9)) (2.8)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from scikit-image>=0.18.1->-r requirement (1).txt (line 9)) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from scikit-image>=0.18.1->-r requirement (1).txt (line 9)) (2022.4.26)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (1.1.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (0.4.0)
# Requirement already satisfied: setuptools in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (61.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (0.25.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (2.10.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (2.8.0.dev2021122109)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (1.45.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (1.16.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (3.20.0rc2)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (4.1.1)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (1.0.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (1.14.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (14.0.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (0.37.1)
# Requirement already satisfied: entrypoints in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from jupyter-client>=5.3.4->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from jupyter-core>=4.6.1->notebook>=6.3.0->-r requirement (1).txt (line 1)) (303)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from nbconvert>=5->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from nbconvert>=5->notebook>=6.3.0->-r requirement (1).txt (line 1)) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from nbconvert>=5->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from nbconvert>=5->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from nbconvert>=5->notebook>=6.3.0->-r requirement (1).txt (line 1)) (4.11.1)
# Requirement already satisfied: tinycss2 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from nbconvert>=5->notebook>=6.3.0->-r requirement (1).txt (line 1)) (1.1.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from nbconvert>=5->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.2.2)
# Requirement already satisfied: bleach in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from nbconvert>=5->notebook>=6.3.0->-r requirement (1).txt (line 1)) (5.0.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from nbconvert>=5->notebook>=6.3.0->-r requirement (1).txt (line 1)) (2.11.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from nbconvert>=5->notebook>=6.3.0->-r requirement (1).txt (line 1)) (2.1.1)
# Requirement already satisfied: fastjsonschema in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from nbformat->notebook>=6.3.0->-r requirement (1).txt (line 1)) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from nbformat->notebook>=6.3.0->-r requirement (1).txt (line 1)) (4.4.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from numba>=0.45.1->librosa==0.9.1->-r requirement (1).txt (line 14)) (0.38.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from pooch>=1.0->librosa==0.9.1->-r requirement (1).txt (line 14)) (2.27.1)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from pooch>=1.0->librosa==0.9.1->-r requirement (1).txt (line 14)) (1.4.4)
# Requirement already satisfied: cffi>=1.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from soundfile>=0.10.2->librosa==0.9.1->-r requirement (1).txt (line 14)) (1.15.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (2.6.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (0.6.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (2.0.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from terminado>=0.8.3->notebook>=6.3.0->-r requirement (1).txt (line 1)) (2.0.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from argon2-cffi->notebook>=6.3.0->-r requirement (1).txt (line 1)) (21.2.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (8.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (1.5.1)
# Requirement already satisfied: psutil in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (5.9.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.1.3)
# Requirement already satisfied: pyyaml>=5.2 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from libcst->ast-tools>=0.1.4->-r requirement (1).txt (line 5)) (6.0)
# Requirement already satisfied: typing-inspect>=0.4.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from libcst->ast-tools>=0.1.4->-r requirement (1).txt (line 5)) (0.7.1)
# Requirement already satisfied: pycparser in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.1->-r requirement (1).txt (line 14)) (2.21)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (1.3.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (3.0.27)
# Requirement already satisfied: jedi>=0.16 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.18.1)
# Requirement already satisfied: backcall in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.7.5)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=6.3.0->-r requirement (1).txt (line 1)) (5.7.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=6.3.0->-r requirement (1).txt (line 1)) (21.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (4.11.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1->-r requirement (1).txt (line 14)) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1->-r requirement (1).txt (line 14)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1->-r requirement (1).txt (line 14)) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.1->-r requirement (1).txt (line 14)) (1.26.9)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from typing-inspect>=0.4.0->libcst->ast-tools>=0.1.4->-r requirement (1).txt (line 5)) (0.4.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.3.0->-r requirement (1).txt (line 1)) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from bleach->nbconvert>=5->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (3.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu>=2.4.1->-r requirement (1).txt (line 11)) (3.2.0)
# Requirement already satisfied: asttokens in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.2.2)
# Requirement already satisfied: executing in c:\users\manami\anaconda3\envs\roadcrack\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.3.0->-r requirement (1).txt (line 1)) (0.8.3)

# %% [markdown]
# ### utility libraries

# %%
import os
import pathlib
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import librosa
import librosa.display
import pandas as pd
import tensorflow.keras as keras

from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display
from pathlib import Path
from IPython.display import Audio
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### declaring hyperparameters

# %%
# Set the seed value for experiment reproducibility.
seed = 42
SR=16000 # resampling as the ram can't handle this much calculation
BATCH_SIZE = 4
AUD_LENGTH = 10
TRAIN_TEST_SPLIT = 0.2
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
# ### All file paths

# %%
# insert needed paths here

# this is the known and unknown dataset path
DATASET_AUDIO_PATH = 'classwise_final_2k/classwise_final_2k'

# this is the random extra data addition folders
ASVSPOOF_DATA_PATH  = 'external files/asvspoof'
LIBRISPEECH_DATA_PATH = 'external files/librispeech'

# this is the evaluation folder for phase 1 and 2
EVAL_PATH_1 = 'spcup_2022_eval_part1'
EVAL_PATH_2 = 'spcup_2022_eval_part1'

### saving paths
CSV_DIR = './'
MODEL_SAVE_DIR = './'
WEIGHT_SAVE_DIR = './'

# %% [markdown]
# # 1. Dataset Generation

# %%
# getting audio dataset path to divide into 3 datasets and also for making tf datasets later

class_names = os.listdir(DATASET_AUDIO_PATH)
print("Our class names: {}".format(class_names,))

audio_paths = []
labels = []
for label, name in enumerate(class_names):
    label = int(name)
    print("Processing speaker {}".format(name,))
    print("Actual Label ",label)
    dir_path = Path(DATASET_AUDIO_PATH) / name
    speaker_sample_paths = [
        os.path.join(dir_path, filepath)
        for filepath in os.listdir(dir_path)
        if filepath.endswith(".wav")
    ]
    audio_paths += speaker_sample_paths
    labels += [label] * len(speaker_sample_paths)

print(
    "Found {} files belonging to {} classes.".format(len(audio_paths), len(class_names))
)
# Out:
# Our class names: ['0', '1', '2', '3', '4', '5']
# Processing speaker 0
# Actual Label  0
# Processing speaker 1
# Actual Label  1
# Processing speaker 2
# Actual Label  2
# Processing speaker 3
# Actual Label  3
# Processing speaker 4
# Actual Label  4
# Processing speaker 5
# Actual Label  5
# Found 11200 files belonging to 6 classes.

# %%
# Split into training and validation
X_train, X_val, y_train, y_val = train_test_split(audio_paths, labels, test_size=TRAIN_TEST_SPLIT, random_state=seed)

# %%
print(len(X_train),len(y_train))
print(len(X_val),len(y_val))
# Out:
# 8960 8960
# 2240 2240

# %%
# utility functions for repeating audio files
def repeated_data(file_path):
    """ This function will take a file path and give out truncated and padded to 10s version waveform"""
    y, sr = librosa.load(file_path,sr=SR)
    aud_length = AUD_LENGTH*sr # making all audio length 10 s and truncating the rest
    duration = librosa.get_duration(y=y, sr=sr)
    if duration < AUD_LENGTH:
        y = np.tile(y, int((aud_length/sr) // duration)+1)
    y = librosa.resample(y[:aud_length], orig_sr=sr, target_sr=SR)
    return y

def repeated_dataset(dataset):
    """ This function generated waveshape dataset"""
    new_ds = []
    for f in dataset:
        new_ds.append(repeated_data(f))
    return new_ds

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, labels, batch_size= BATCH_SIZE, 
                 n_classes=6, shuffle=True):
        'Initialization'
        self.dim = AUD_LENGTH * SR
        self.batch_size = batch_size
        self.labels = labels
        self.shuffle = shuffle
        self.list_IDs = list_IDs
        self.on_epoch_end()

    def path_to_audio(self,path):
        """Reads and decodes an audio file."""
        return repeated_data(path)

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Generate data
        X, y = self.__data_generation(indexes)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples'
        
        X = []
        y = []
        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            # Store sample
            _tempx = self.path_to_audio(self.list_IDs[ID])
            #_tempx = self.spect_audio(_tempx)
            X.append(_tempx)

            # Store class
            y.append(self.labels[ID])

        return np.reshape(np.array(X), (self.batch_size,SR*AUD_LENGTH,1)).astype(np.float32),np.array(y).astype(np.float32)

# %%
# generating tf datasets
train_ds = DataGenerator(X_train,y_train)
valid_ds = DataGenerator(X_val,y_val)

# %% [markdown]
# # 2. Building A Model

# %%
### model 2
def DilatedConvModule(xx, filters):
    
    xx1 = tf.keras.layers.Conv1D(filters, kernel_size = 9,dilation_rate=1, padding= "same")(xx)
    xx1 = tf.keras.layers.BatchNormalization()(xx1)
    xx1 = tf.keras.layers.ReLU()(xx1)
    
    xx2 = tf.keras.layers.Conv1D(filters, kernel_size = 7,dilation_rate=2, padding= "same")(xx1)
    xx2 = tf.keras.layers.BatchNormalization()(xx2)
    xx2 = tf.keras.layers.ReLU()(xx2)
    
    xx4 = tf.keras.layers.Conv1D(filters, kernel_size = 3,dilation_rate=4, padding= "same")(xx2)
    xx4 = tf.keras.layers.BatchNormalization()(xx4)
    xx4 = tf.keras.layers.ReLU()(xx4)
    
    xx8 = tf.keras.layers.Conv1D(filters, kernel_size = 1,dilation_rate=8, padding= "same")(xx4)
    xx8 = tf.keras.layers.BatchNormalization()(xx8)
    xx8 = tf.keras.layers.ReLU()(xx8)
    #concat
    yy = tf.keras.layers.Concatenate(axis=1)([xx1,xx2,xx4,xx8])
    yy = tf.keras.layers.BatchNormalization()(yy)
    yy = tf.keras.layers.ReLU()(yy)
    
    return yy

def build_model(input_shape, num_classes):
    inputs = tf.keras.layers.Input(shape=input_shape, name="input")
    x      = tf.keras.layers.Conv1D(16, kernel_size = 9,dilation_rate=1, padding= "same")(inputs)
    x      = tf.keras.layers.BatchNormalization()(x)
    x      = tf.keras.layers.ReLU()(x)
    x      = tf.keras.layers.MaxPool1D(pool_size = 4)(x)
    
    # stacked resnet modules
    # inc1
    x      = DilatedConvModule(x,32)
    x      = tf.keras.layers.MaxPool1D(pool_size = 4)(x)
    # inc2
    x      = DilatedConvModule(x,64)
    x      = tf.keras.layers.MaxPool1D(pool_size = 4)(x)
    # inc4
    x      = DilatedConvModule(x,128)
    x      = tf.keras.layers.MaxPool1D(pool_size = 4)(x)
    # inc8
    x      = DilatedConvModule(x,256)
    x      = tf.keras.layers.MaxPool1D(pool_size =  x.shape[-1])(x)
    
    x      = tf.keras.layers.GlobalAveragePooling1D()(x)
    
    x      = tf.keras.layers.Flatten()(x)
    x      = tf.keras.layers.Dense(64, activation="relu")(x)
    x      = tf.keras.layers.Dense(32, activation="relu")(x)
    x      = tf.keras.layers.Dropout(0.25)(x)
    
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax", name="output")(x)
    
    return tf.keras.models.Model(inputs=inputs, outputs=outputs)


aud_length = SR*AUD_LENGTH

model = build_model((aud_length, 1), len(class_names))

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 160000, 1)]  0           []
#
#  conv1d (Conv1D)                (None, 160000, 16)   160         ['input[0][0]']
#
#  batch_normalization (BatchNorm  (None, 160000, 16)  64          ['conv1d[0][0]']
#  alization)
#
#  re_lu (ReLU)                   (None, 160000, 16)   0           ['batch_normalization[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 40000, 16)    0           ['re_lu[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 40000, 32)    4640        ['max_pooling1d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 40000, 32)   128         ['conv1d_1[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 40000, 32)    0           ['batch_normalization_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 40000, 32)    7200        ['re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 40000, 32)   128         ['conv1d_2[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 40000, 32)    0           ['batch_normalization_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 40000, 32)    3104        ['re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 40000, 32)   128         ['conv1d_3[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 40000, 32)    0           ['batch_normalization_3[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 40000, 32)    1056        ['re_lu_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 40000, 32)   128         ['conv1d_4[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 40000, 32)    0           ['batch_normalization_4[0][0]']
#
#  concatenate (Concatenate)      (None, 160000, 32)   0           ['re_lu_1[0][0]',
#                                                                   're_lu_2[0][0]',
#                                                                   're_lu_3[0][0]',
#                                                                   're_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 160000, 32)  128         ['concatenate[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 160000, 32)   0           ['batch_normalization_5[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 40000, 32)   0           ['re_lu_5[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 40000, 64)    18496       ['max_pooling1d_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 40000, 64)   256         ['conv1d_5[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 40000, 64)    0           ['batch_normalization_6[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 40000, 64)    28736       ['re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 40000, 64)   256         ['conv1d_6[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 40000, 64)    0           ['batch_normalization_7[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 40000, 64)    12352       ['re_lu_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 40000, 64)   256         ['conv1d_7[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 40000, 64)    0           ['batch_normalization_8[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 40000, 64)    4160        ['re_lu_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 40000, 64)   256         ['conv1d_8[0][0]']
#  rmalization)
#
#  re_lu_9 (ReLU)                 (None, 40000, 64)    0           ['batch_normalization_9[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 160000, 64)   0           ['re_lu_6[0][0]',
#                                                                   're_lu_7[0][0]',
#                                                                   're_lu_8[0][0]',
#                                                                   're_lu_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 160000, 64)  256         ['concatenate_1[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 160000, 64)   0           ['batch_normalization_10[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 40000, 64)   0           ['re_lu_10[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 40000, 128)   73856       ['max_pooling1d_2[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 40000, 128)  512         ['conv1d_9[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 40000, 128)   0           ['batch_normalization_11[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 40000, 128)   114816      ['re_lu_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 40000, 128)  512         ['conv1d_10[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 40000, 128)   0           ['batch_normalization_12[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 40000, 128)   49280       ['re_lu_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 40000, 128)  512         ['conv1d_11[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 40000, 128)   0           ['batch_normalization_13[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 40000, 128)   16512       ['re_lu_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 40000, 128)  512         ['conv1d_12[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 40000, 128)   0           ['batch_normalization_14[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 160000, 128)  0           ['re_lu_11[0][0]',
#                                                                   're_lu_12[0][0]',
#                                                                   're_lu_13[0][0]',
#                                                                   're_lu_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 160000, 128)  512        ['concatenate_2[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 160000, 128)  0           ['batch_normalization_15[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 40000, 128)  0           ['re_lu_15[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 40000, 256)   295168      ['max_pooling1d_3[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 40000, 256)  1024        ['conv1d_13[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 40000, 256)   0           ['batch_normalization_16[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 40000, 256)   459008      ['re_lu_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 40000, 256)  1024        ['conv1d_14[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 40000, 256)   0           ['batch_normalization_17[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 40000, 256)   196864      ['re_lu_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 40000, 256)  1024        ['conv1d_15[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 40000, 256)   0           ['batch_normalization_18[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 40000, 256)   65792       ['re_lu_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 40000, 256)  1024        ['conv1d_16[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 40000, 256)   0           ['batch_normalization_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 160000, 256)  0           ['re_lu_16[0][0]',
#                                                                   're_lu_17[0][0]',
#                                                                   're_lu_18[0][0]',
#                                                                   're_lu_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 160000, 256)  1024       ['concatenate_3[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 160000, 256)  0           ['batch_normalization_20[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 625, 256)    0           ['re_lu_20[0][0]']
#
#  global_average_pooling1d (Glob  (None, 256)         0           ['max_pooling1d_4[0][0]']
#  alAveragePooling1D)
#
#  flatten (Flatten)              (None, 256)          0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 64)           16448       ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 32)           2080        ['dense[0][0]']
#
#  dropout (Dropout)              (None, 32)           0           ['dense_1[0][0]']
#
#  output (Dense)                 (None, 6)            198         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 1,379,590
# Trainable params: 1,374,758
# Non-trainable params: 4,832
# __________________________________________________________________________________________________

# %%
# configuring the run
# Compile the model using Adam's default learning rate
model.compile(
    optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)

# Add callbacks:
# 'EarlyStopping' to stop training when the model is not enhancing anymore
# 'ModelCheckPoint' to always keep the model that has the best val_accuracy
weight_save_filename = "weight_inceptionnet_final_50ep.h5"

lr_reduce = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, verbose=1, mode='min', min_lr=1e-9)
earlystopping_cb = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.001, patience=10, mode='min', restore_best_weights=True)
mdlcheckpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    weight_save_filename, monitor="val_accuracy", save_best_only=True,save_weights_only=True
)

# %% [markdown]
# # 3. Training the Model

# %%
EPOCHS = 50
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=valid_ds,
    callbacks=[lr_reduce,earlystopping_cb, mdlcheckpoint_cb],
)
model.save("model_inceptionnet_final_50ep.h5")
# Out:
# Epoch 1/50
# 2240/2240 [==============================] - 823s 360ms/step - loss: 0.8952 - accuracy: 0.6295 - val_loss: 0.5108 - val_accuracy: 0.7853 - lr: 0.0010
# Epoch 2/50
# 1540/2240 [===================>..........] - ETA: 3:49 - loss: 0.5509 - accuracy: 0.7638
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\sp cup 2022\Students_Procastinating_ID27592_code_report\inceptionnet_train_pipeline_waveraw.ipynb Cell 22' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/sp%20cup%202022/Students_Procastinating_ID27592_code_report/inceptionnet_train_pipeline_waveraw.ipynb#ch0000022?line=0'>1</a> EPOCHS = 50
# ----> <a href='vscode-notebook-cell:/d%3A/sp%20cup%202022/Students_Procastinating_ID27592_code_report/inceptionnet_train_pipeline_waveraw.ipynb#ch0000022?line=1'>2</a> history = model.fit(
#       <a href='vscode-notebook-cell:/d%3A/sp%20cup%202022/Students_Procastinating_ID27592_code_report/inceptionnet_train_pipeline_waveraw.ipynb#ch0000022?line=2'>3</a>     train_ds,
#       <a href='vscode-notebook-cell:/d%3A/sp%20cup%202022/Students_Procastinating_ID27592_code_report/inceptionnet_train_pipeline_waveraw.ipynb#ch0000022?line=3'>4</a>     epochs=EPOCHS,
#       <a href='vscode-notebook-cell:/d%3A/sp%20cup%202022/Students_Procastinating_ID27592_code_report/inceptionnet_train_pipeline_waveraw.ipynb#ch0000022?line=4'>5</a>     validation_data=valid_ds,
#       <a href='vscode-notebook-cell:/d%3A/sp%20cup%202022/Students_Procastinating_ID27592_code_report/inceptionnet_train_pipeline_waveraw.ipynb#ch0000022?line=5'>6</a>     callbacks=[lr_reduce,earlystopping_cb, mdlcheckpoint_cb],
#       <a href='vscode-notebook-cell:/d%3A/sp%20cup%202022/Students_Procastinating_ID27592_code_report/inceptionnet_train_pipeline_waveraw.ipynb#ch0000022?line=6'>7</a> )
#       <a href='vscode-notebook-cell:/d%3A/sp%20cup%202022/Students_Procastinating_ID27592_code_report/inceptionnet_train_pipeline_waveraw.ipynb#ch0000022?line=7'>8</a> model.save("model_inceptionnet_final_50ep.h5")
#
# File ~\anaconda3\envs\RoadCrack\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\RoadCrack\lib\site-packages\keras\engine\training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/engine/training.py?line=1376'>1377</a> with tf.profiler.experimental.Trace(
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/engine/training.py?line=1377'>1378</a>     'train',
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/engine/training.py?line=1378'>1379</a>     epoch_num=epoch,
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/engine/training.py?line=1379'>1380</a>     step_num=step,
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/engine/training.py?line=1380'>1381</a>     batch_size=batch_size,
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/engine/training.py?line=1381'>1382</a>     _r=1):
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/engine/training.py?line=1382'>1383</a>   callbacks.on_train_batch_begin(step)
# -> <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/engine/training.py?line=1383'>1384</a>   tmp_logs = self.train_function(iterator)
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/engine/training.py?line=1384'>1385</a>   if data_handler.should_sync:
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/keras/engine/training.py?line=1385'>1386</a>     context.async_wait()
#
# File ~\anaconda3\envs\RoadCrack\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=147'>148</a> filtered_tb = None
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=148'>149</a> try:
# --> <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=149'>150</a>   return fn(*args, **kwargs)
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\RoadCrack\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=911'>912</a> compiler = "xla" if self._jit_compile else "nonXla"
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=913'>914</a> with OptionalXlaContext(self._jit_compile):
# --> <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=914'>915</a>   result = self._call(*args, **kwds)
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=916'>917</a> new_tracing_count = self.experimental_get_tracing_count()
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=917'>918</a> without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\envs\RoadCrack\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=943'>944</a>   self._lock.release()
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=944'>945</a>   # In this case we have created variables on the first call, so we run the
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=945'>946</a>   # defunned version which is guaranteed to never create variables.
# --> <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=946'>947</a>   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=947'>948</a> elif self._stateful_fn is not None:
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=948'>949</a>   # Release the lock early so that multiple threads can perform the call
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=949'>950</a>   # in parallel.
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/def_function.py?line=950'>951</a>   self._lock.release()
#
# File ~\anaconda3\envs\RoadCrack\lib\site-packages\tensorflow\python\eager\function.py:2956, in Function.__call__(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=2952'>2953</a> with self._lock:
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=2953'>2954</a>   (graph_function,
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=2954'>2955</a>    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=2955'>2956</a> return graph_function._call_flat(
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=2956'>2957</a>     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\anaconda3\envs\RoadCrack\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=1848'>1849</a> possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=1849'>1850</a> if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=1850'>1851</a>     and executing_eagerly):
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=1851'>1852</a>   # No tape is watching; skip to running the function.
# -> <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=1852'>1853</a>   return self._build_call_outputs(self._inference_function.call(
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=1853'>1854</a>       ctx, args, cancellation_manager=cancellation_manager))
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=1854'>1855</a> forward_backward = self._select_forward_and_backward_functions(
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=1855'>1856</a>     args,
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=1856'>1857</a>     possible_gradient_type,
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=1857'>1858</a>     executing_eagerly)
#    <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=1858'>1859</a> forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\envs\RoadCrack\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=496'>497</a> with _InterpolateFunctionError(self):
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=497'>498</a>   if cancellation_manager is None:
# --> <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=498'>499</a>     outputs = execute.execute(
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=499'>500</a>         str(self.signature.name),
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=500'>501</a>         num_outputs=self._num_outputs,
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=501'>502</a>         inputs=args,
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=502'>503</a>         attrs=attrs,
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=503'>504</a>         ctx=ctx)
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=504'>505</a>   else:
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=505'>506</a>     outputs = execute.execute_with_cancellation(
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=506'>507</a>         str(self.signature.name),
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=507'>508</a>         num_outputs=self._num_outputs,
#    (...)
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=510'>511</a>         ctx=ctx,
#     <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/function.py?line=511'>512</a>         cancellation_manager=cancellation_manager)
#
# File ~\anaconda3\envs\RoadCrack\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/execute.py?line=51'>52</a> try:
#      <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/execute.py?line=52'>53</a>   ctx.ensure_initialized()
# ---> <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/execute.py?line=53'>54</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/execute.py?line=54'>55</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> except core._NotOkStatusException as e:
#      <a href='file:///c%3A/Users/manami/anaconda3/envs/RoadCrack/lib/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   if name is not None:
#
# KeyboardInterrupt:
